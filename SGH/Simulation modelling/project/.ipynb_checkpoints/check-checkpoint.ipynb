# %%
from ple.games.flappybird import FlappyBird
from ple import PLE


game = FlappyBird()
p = PLE(game, fps=30, display_screen=True)
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %%
# agent = myAgentHere(allowed_actions=p.getActionSet())
p.getActionSet()

# p.init()
# reward = 0.0

# for i in range(nb_frames):
#     if p.game_over():
#         p.reset_game()

#     observation = p.getScreenRGB()
#     action = agent.pickAction(reward, observation)
#     reward = p.act(action)
# Out:
# [119, None]

# %%
from ple.games.flappybird import FlappyBird
from ple import PLE

game = FlappyBird()
p = PLE(game, fps=30, display_screen=True, force_fps=False)
p.init()
actions = p.getActionSet()
action_dict = {0: actions[1], 1:actions[0]}
action_dict
# reward = 0.0

# for i in range(10000):
#    if p.game_over():
#            p.reset_game()

#    state = p.getScreenRGB()
#    action = 1
#    reward = p.act(action_dict[action])
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom
# {0: None, 1: 119}

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-df90608ebaa4> in <module>
#       1 import random
# ----> 2 import cPickle as pickle
#       3 import numpy as np
#       4 from evostra import EvolutionStrategy
#       5 from ple import PLE
#
# ModuleNotFoundError: No module named 'cPickle'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def smooth(x):
    # last 100
    n = len(x)
    y = np.zeros(n)
    for i in range(n):
        start = max(0, i - 99)
        y[i] = float(x[start:(i + 1)].sum()) / (i - start + 1)
    return y

# %%
j = np.load('./results_original/es_flappy_results.npz')

returns = j['train']

plt.plot(returns)
plt.plot(smooth(np.array(returns)))
plt.title("Train returns.\nPipe gap = 125, pop.size = 30, iterations = 300")
plt.xlabel("Iterations")
plt.ylabel("Avg Reward")
plt.show()

# %%
j = np.load('./results_2/es_flappy_results.npz')

returns = j['train']

plt.plot(returns)
plt.plot(smooth(np.array(returns)))
plt.title("Train returns.\nPipe gap = 110, pop.size = 75, iterations = 500")
plt.xlabel("Iterations")
plt.ylabel("Avg Reward")
plt.show()

# %%
j = np.load('./results_3/es_flappy_results.npz')

returns = j['train']

plt.plot(returns)
plt.plot(smooth(np.array(returns)))
plt.title("Train returns.\nPipe gap = 110, pop.size = 30, iterations = 400")
plt.xlabel("Iterations")
plt.ylabel("Avg Reward")
plt.show()
