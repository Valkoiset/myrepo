# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import random
# from sklearn.model_selection import train_test_split

# %%
# df = pd.read_csv('data/weatherAUS.csv')
df = pd.read_csv('data/rain.csv')

# %%
df
# Out:
#         Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall  \
# 0                1  2008-12-01   Albury     13.4     22.9       0.6
# 1                2  2008-12-02   Albury      7.4     25.1       0.0
# 2                3  2008-12-03   Albury     12.9     25.7       0.0
# 3                4  2008-12-04   Albury      9.2     28.0       0.0
# 4                5  2008-12-05   Albury     17.5     32.3       1.0
# ...            ...         ...      ...      ...      ...       ...
# 112920      142189  2017-06-20    Uluru      3.5     21.8       0.0
# 112921      142190  2017-06-21    Uluru      2.8     23.4       0.0
# 112922      142191  2017-06-22    Uluru      3.6     25.3       0.0
# 112923      142192  2017-06-23    Uluru      5.4     26.9       0.0
# 112924      142193  2017-06-24    Uluru      7.8     27.0       0.0
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0                W             44          W        WNW            20
# ...

# %%
df.shape
# Out:
# (112925, 20)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112925 entries, 0 to 112924
# Data columns (total 20 columns):
# Unnamed: 0       112925 non-null int64
# Date             112925 non-null object
# Location         112925 non-null object
# MinTemp          112925 non-null float64
# MaxTemp          112925 non-null float64
# Rainfall         112925 non-null float64
# WindGustDir      112925 non-null object
# WindGustSpeed    112925 non-null int64
# WindDir9am       112925 non-null object
# WindDir3pm       112925 non-null object
# WindSpeed9am     112925 non-null int64
# WindSpeed3pm     112925 non-null int64
# Humidity9am      112925 non-null int64
# Humidity3pm      112925 non-null int64
# Pressure9am      112925 non-null float64
# Pressure3pm      112925 non-null float64
# Temp9am          112925 non-null float64
# Temp3pm          112925 non-null float64
# RainToday        112925 non-null int64
# RainTomorrow     112925 non-null int64
# dtypes: float64(7), int64(8), object(5)
# ...

# %%
df['RainTomorrow'].value_counts()/len(df)
# Out:
# 0    0.778446
# 1    0.221554
# Name: RainTomorrow, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 4))
ax = sns.countplot(y="RainTomorrow", data=df, palette="Set1")
plt.show()

# %%
# find categorical variables
categorical = [var for var in df.columns if df[var].dtype=='O']
print('There are {} categorical variables\n'.format(len(categorical)))
print('The categorical variables are :', categorical)
# Out:
# There are 5 categorical variables
#
# The categorical variables are : ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']

# %%
df[categorical].head()
# Out:
#          Date Location WindGustDir WindDir9am WindDir3pm
# 0  2008-12-01   Albury           W          W        WNW
# 1  2008-12-02   Albury         WNW        NNW        WSW
# 2  2008-12-03   Albury         WSW          W        WSW
# 3  2008-12-04   Albury          NE         SE          E
# 4  2008-12-05   Albury           W        ENE         NW

# %%
correlation = df.corr()
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Rain in Australia Dataset')
ax = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)           
plt.show()

# %%
df = df.drop(['Unnamed: 0'], axis=1)
# df.columns

# %%
# Out:
# (112925, 19)

# %%
# df.isnull().sum()
df['Humidity3pm'].describe()
# Out:
# count    112925.000000
# mean         50.669055
# std          20.768550
# min           0.000000
# 25%          36.000000
# 50%          51.000000
# 75%          65.000000
# max         100.000000
# Name: Humidity3pm, dtype: float64

# %%
ori = [4,1,2,1,3]   # some elements inside need to be changed 
num_list = [2,1,1,1]    # numbers that represent index in ori

for num in num_list:
    ori[num] = random.randint(1,4)
print(ori)
# Out:
# [4, 1, 1, 1, 3]

# %%
random.randint(1,4)
# Out:
# 1

# %% [markdown]
# Humidity9am, Humidity3pm, Pressure9am, Pressure3pm

# %%
random.seed(42)
index = list(range(1, 112926))
index_na = random.sample(index, 27654)
# len(index)
# len(index_na)
# index_na
df['Humidity9am'][index_na] = None
# df['Humidity3pm'][index_na]
df['Humidity3pm'][index_na] = None
df['Pressure9am'][index_na] = None
df['Pressure3pm'][index_na] = None
# Out:
# 83811   NaN
# 14593   NaN
# 3279    NaN
# 97197   NaN
# 36049   NaN
#          ..
# 67331   NaN
# 26105   NaN
# 14536   NaN
# 87979   NaN
# 2609    NaN
# Name: Humidity3pm, Length: 27654, dtype: float64

# %% [markdown]
# Pressure3pm

# %%
# for num in num_list:
#     ori[num] = random.randint(1,4)
# print(ori)
# Out:
# [4, 1, 2, 1, 3]

# %%
random.seed(28)
index = list(range(1, 112926))
index_na = random.sample(index, 31491)
# len(index)
# len(index_na)
# index_na
df['Pressure3pm'][index_na] = None
df['Pressure3pm'][index_na]
# Out:
# /Users/valkoiset/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# 14806    NaN
# 97302    NaN
# 17152    NaN
# 71521    NaN
# 78285    NaN
#           ..
# 110690   NaN
# 31404    NaN
# 91462    NaN
# 9772     NaN
# 72373    NaN
# Name: Pressure3pm, Length: 31491, dtype: float64

# %%
df
# Out:
#         Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall  \
# 0                1  2008-12-01   Albury     13.4     22.9       0.6
# 1                2  2008-12-02   Albury      7.4     25.1       0.0
# 2                3  2008-12-03   Albury     12.9     25.7       0.0
# 3                4  2008-12-04   Albury      9.2     28.0       0.0
# 4                5  2008-12-05   Albury     17.5     32.3       1.0
# ...            ...         ...      ...      ...      ...       ...
# 112920      142189  2017-06-20    Uluru      3.5     21.8       0.0
# 112921      142190  2017-06-21    Uluru      2.8     23.4       0.0
# 112922      142191  2017-06-22    Uluru      3.6     25.3       0.0
# 112923      142192  2017-06-23    Uluru      5.4     26.9       0.0
# 112924      142193  2017-06-24    Uluru      7.8     27.0       0.0
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0                W             44          W        WNW            20
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# WindGustDir          0
# WindGustSpeed        0
# WindDir9am           0
# WindDir3pm           0
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm      27654
# Pressure9am          0
# Pressure3pm      31491
# Temp9am              0
# Temp3pm              0
# RainToday            0
# RainTomorrow         0
# dtype: int64

# %%
df.to_csv('rain_with_NA.csv')

# %%
df.shape
# Out:
# (112925, 20)

# %%
df.head()
# Out:
#    Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  \
# 0           1  2008-12-01   Albury     13.4     22.9       0.6           W
# 1           2  2008-12-02   Albury      7.4     25.1       0.0         WNW
# 2           3  2008-12-03   Albury     12.9     25.7       0.0         WSW
# 3           4  2008-12-04   Albury      9.2     28.0       0.0          NE
# 4           5  2008-12-05   Albury     17.5     32.3       1.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0             44          W        WNW            20            24
# 1             44        NNW        WSW             4            22
# 2             46          W        WSW            19            26
# 3             24         SE          E            11             9
# 4             41        ENE         NW             7            20
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm  \
# ...
